# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_excel('emailc.xls')
df
# Out:
#     dfhdfd                                            Email 1  \
# 0        1              tccxmbgfjgjdfhdfdgu@mxstx.dfhdfgfjgjg
# 1        2  utbudfhdfgfjgjdfhdfus@gfjgjuguttstgfjgjuutcldf...
# 2        3                               jxt.lxq@9fuf.ddfhdfm
# 3        4  dfhdftfdfhdf@sussuxtgfjgjxvulcldfhdftdfhdfc.dd...
# 4        5  mxggdfhdfugfjgjdfhdfycgfjgjdfhdfft@gb-m84019.9...
# 5        6      tgfjgjdfhdfsuulldfhdfdfhdftt2@xdfhdfl.ddfhdfm
# 6        7                        umxdfhdfl@tuuusgb.cdfhdf.uk
# 7        8  t9fuftccg.dfhdfvymuddfhdfcxlggfjgjdfhdfub@9fuf...
# 8        9                          t.bxxtugfjgj@9fuf.ddfhdfm
# 9       10              sxgfjgjxubuxgfjgjsdfhdft@9fuf.ddfhdfm
# 10      11               dutdfhdfsu.kdfhdfgfjgjk@9fuf.ddfhdfm
# 11      12            sxgfjgjxu.sxtdugfjgjs@gb-c87004.9fuf.uk
# 12      13   clxdfhdfgfjgju.ggfjgjugdfhdfgfjgjy5@9fuf.ddfhdfm
# 13      14         ldfhdfqugfjgj.stdfhdftddfhdft@9fuf.ddfhdfm
# ...

# %%
email_columns = ['Email 1', 'Multiple email', 'Email 3', 'Email 4',
                'Email 4.1']

# %%
df_emails = df[['Email 1', 'Multiple email', 'Email 3', 'Email 4',
       'Email 4.1']]

# %%
dfemails = dfemails.apply(lambda x: x.str.split(';'))

# %%
email_list = []
for i in dfemails.columns:
    for j in dfemails['Email 1']:
        for k in j:
            email_list.extend(j)

# %%
pd.DataFrame(email_list).to_csv("poooaaaar.csv", index=False)

# %%
pd.read_csv("poooaaaar.csv")
# Out:
#                                                      0
# 0                tccxmbgfjgjdfhdfdgu@mxstx.dfhdfgfjgjg
# 1    utbudfhdfgfjgjdfhdfus@gfjgjuguttstgfjgjuutcldf...
# 2                                 jxt.lxq@9fuf.ddfhdfm
# 3    dfhdftfdfhdf@sussuxtgfjgjxvulcldfhdftdfhdfc.dd...
# 4    mxggdfhdfugfjgjdfhdfycgfjgjdfhdfft@gb-m84019.9...
# 5        tgfjgjdfhdfsuulldfhdfdfhdftt2@xdfhdfl.ddfhdfm
# 6                          umxdfhdfl@tuuusgb.cdfhdf.uk
# 7    t9fuftccg.dfhdfvymuddfhdfcxlggfjgjdfhdfub@9fuf...
# 8                            t.bxxtugfjgj@9fuf.ddfhdfm
# 9                sxgfjgjxubuxgfjgjsdfhdft@9fuf.ddfhdfm
# 10                dutdfhdfsu.kdfhdfgfjgjk@9fuf.ddfhdfm
# 11             sxgfjgjxu.sxtdugfjgjs@gb-c87004.9fuf.uk
# 12    clxdfhdfgfjgju.ggfjgjugdfhdfgfjgjy5@9fuf.ddfhdfm
# 13          ldfhdfqugfjgj.stdfhdftddfhdft@9fuf.ddfhdfm
# 14   mxdfhdfl@tuquxllmuddfhdfcxlbgfjgjxctdfhdfcu.dd...
# 15    m.bdfhdfgfjgjtuqdfhdfck-uzukdfhdful@9fuf.ddfhdfm
# ...
